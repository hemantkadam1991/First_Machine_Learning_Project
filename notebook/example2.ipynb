# %%
url= 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
import os

# %%
os.path.basename(url)
# Out:
# 'housing.tgz'

# %%
file_path =r"C:\Users\Hemant Kadam\Machine_Learning_Projects_Live\First_Machine_Learning_Project\config"

# %%
os.listdir(file_path)
# Out:
# ['config.yaml']

# %%
os.listdir(file_path)[0]
# Out:
# 'config.yaml'

# %%
## Data ingestion

# %%
import pandas as pd

# %%
csv_file_path = r"C:\Users\Hemant Kadam\Machine_Learning_Projects_Live\First_Machine_Learning_Project\housing\artifact\data_ingestion\2023-10-13-19-24-31\raw_data\housing.csv"
housing_data_frame = pd.read_csv(csv_file_path)
housing_data_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
housing_data_frame["median_income"].plot(kind="hist")

# %%
import numpy as np

# %%
housing_data_frame["income_cat"] = pd.cut (
    housing_data_frame["median_income"],
    bins=[0.0, 1.5, 3.0, 4.5, 6.0, np.inf],
    labels = [1, 2, 3, 4, 5]
    )

# %%
housing_data_frame.income_cat.value_counts()
# Out:
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: income_cat, dtype: int64

# %%
plt.pie(housing_data_frame.income_cat.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x3f925e7438>,
# ...
#  [Text(0.49759850713241616, 0.9810176989736684, ''),
#   Text(-1.0978272902668031, -0.06910311675640082, ''),
#   Text(0.052385887306755786, -1.0987518913799803, ''),
#   Text(0.9017710292481974, -0.6299277822168561, ''),
#   Text(1.0914015713324503, -0.1372683870855143, '')])

# %%
plt.pie(housing_data_frame.income_cat.value_counts(), labels=housing_data_frame.income_cat.value_counts().index)
plt.show()

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
split.split(housing_data_frame, housing_data_frame["income_cat"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-577ddf816ec3> in <module>
# ----> 1 split.split(housing_data_frame, housing_data_frame["income_cat"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1771         to an integer.
#    1772         """
# -> 1773         y = check_array(y, ensure_2d=False, dtype=None)
#    1774         return super(StratifiedShuffleSplit, self).split(X, y, groups)
#    1775
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     478     # DataFrame), and store them. If not, store None.
#     479     dtypes_orig = None
# ...

# %%
for train_ix,test_ix in split.split(housing_data_frame, housing_data_frame["income_cat"]):
    print ( train_ix,test_ix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-01a67c0da5ea> in <module>
# ----> 1 for train_ix,test_ix in split.split(housing_data_frame, housing_data_frame["income_cat"]):
#       2     print ( train_ix,test_ix)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1771         to an integer.
#    1772         """
# -> 1773         y = check_array(y, ensure_2d=False, dtype=None)
#    1774         return super(StratifiedShuffleSplit, self).split(X, y, groups)
#    1775
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     478     # DataFrame), and store them. If not, store None.
# ...

# %%
train_ix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-721de9cd64e3> in <module>
# ----> 1 train_ix
#
# NameError: name 'train_ix' is not defined

# %%
## Data Validation

# %%
housing_data_frame.columns, housing_data_frame.dtypes
# Out:
# (Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'ocean_proximity', 'income_cat'],
#        dtype='object'), longitude              float64
#  latitude               float64
#  housing_median_age     float64
#  total_rooms            float64
#  total_bedrooms         float64
#  population             float64
#  households             float64
#  median_income          float64
#  median_house_value     float64
#  ocean_proximity         object
#  income_cat            category
#  dtype: object)

# %%
housing_data_frame.dtypes.index , housing_data_frame.columns
# Out:
# (Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'ocean_proximity', 'income_cat'],
#        dtype='object'),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'ocean_proximity', 'income_cat'],
#        dtype='object'))

# %%
housing_data_frame.dtypes.index , housing_data_frame.dtypes.values
# Out:
# (Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'ocean_proximity', 'income_cat'],
#        dtype='object'),
#  array([dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('float64'), dtype('float64'), dtype('O'),
#         CategoricalDtype(categories=[1, 2, 3, 4, 5], ordered=True)],
#        dtype=object))

# %%
housing_data_frame.dtypes.values
# Out:
# array([dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64'), dtype('O'),
#        CategoricalDtype(categories=[1, 2, 3, 4, 5], ordered=True)],
#       dtype=object)

# %%
list(map(lambda x:str(x).replace ("dtype('","").replace(" ')","") , housing_data_frame.dtypes.values))
# Out:
# ['float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'object',
#  'category']

# %%
data_type = list(map(lambda x:str(x).replace ("dtype('","").replace(" ')","") , housing_data_frame.dtypes.values))

# %%
column =housing_data_frame.columns

# %%
dict(zip(column,data_type))
# Out:
# {'longitude': 'float64',
#  'latitude': 'float64',
#  'housing_median_age': 'float64',
#  'total_rooms': 'float64',
#  'total_bedrooms': 'float64',
#  'population': 'float64',
#  'households': 'float64',
#  'median_income': 'float64',
#  'median_house_value': 'float64',
#  'ocean_proximity': 'object',
#  'income_cat': 'category'}

# %%
##schema for datatype is ready.
